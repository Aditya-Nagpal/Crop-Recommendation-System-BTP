# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %%
data=pd.read_csv('Crop_recommendation.csv')
data=data.sample(frac=1) 
data.head()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall     label
# 1181    2  36  31    30.902252  49.959555  5.731719   91.775226     mango
# 669     9  35  20    27.415035  80.980047  6.913809   40.531732  mungbean
# 1661   12   6   8    30.848350  92.867737  6.388617  107.414268    orange
# 1961  107  43  18    22.426733  81.534808  6.745104   65.544758    cotton
# 207    59  70  84    17.334868  18.749270  7.550808   82.617347  chickpea

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2200 entries, 1181 to 1289
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 154.7+ KB

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
data['label'].value_counts()
# Out:
# label
# mango          100
# mungbean       100
# banana         100
# coconut        100
# watermelon     100
# lentil         100
# apple          100
# pigeonpeas     100
# muskmelon      100
# papaya         100
# maize          100
# coffee         100
# jute           100
# mothbeans      100
# kidneybeans    100
# pomegranate    100
# blackgram      100
# grapes         100
# chickpea       100
# cotton         100
# orange         100
# rice           100
# Name: count, dtype: int64

# %%
label_map={}
crops=data['label'].unique()
val=1
for crop in crops:
    label_map[crop]=val
    val+=1
data['label_num']=data['label'].map(label_map)
label_map
# Out:
# {'mango': 1,
#  'mungbean': 2,
#  'orange': 3,
#  'cotton': 4,
#  'chickpea': 5,
#  'grapes': 6,
#  'blackgram': 7,
#  'pomegranate': 8,
#  'kidneybeans': 9,
#  'mothbeans': 10,
#  'jute': 11,
#  'coffee': 12,
#  'maize': 13,
#  'papaya': 14,
#  'muskmelon': 15,
#  'pigeonpeas': 16,
#  'apple': 17,
#  'lentil': 18,
#  'watermelon': 19,
#  'coconut': 20,
#  'banana': 21,
#  'rice': 22}

# %%
data.drop(columns=['label'],axis=1,inplace=True)
data.head()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label_num
# 1181    2  36  31    30.902252  49.959555  5.731719   91.775226          1
# 669     9  35  20    27.415035  80.980047  6.913809   40.531732          2
# 1661   12   6   8    30.848350  92.867737  6.388617  107.414268          3
# 1961  107  43  18    22.426733  81.534808  6.745104   65.544758          4
# 207    59  70  84    17.334868  18.749270  7.550808   82.617347          5

# %% [markdown]
# # Train Test Split

# %%
X=data.drop(columns=['label_num'],axis=1)
Y=data['label_num']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled_X=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(scaled_X,Y,train_size=0.8,random_state=42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((1760, 7), (440, 7), (1760,), (440,))

# %% [markdown]
# # Implementing models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %%
models={
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'Support Vector Machine': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Extra Trees': ExtraTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Bagging': BaggingClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
}

# %%
for name,model in models.items():
    model.fit(X_train,Y_train)
    predictions=model.predict(X_test)
    print(f"{name} : Classification report")
    print(classification_report(Y_test,predictions),'\n')
    print(f"{name} Precision score : ", precision_score(Y_test,predictions,average="macro"),'\n')
    print(f"{name} Recall score : ", recall_score(Y_test,predictions,average="macro"),'\n')
    print("*******************************************")
# Out:
# Logistic Regression : Classification report
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        22
#            2       0.87      1.00      0.93        20
#            3       1.00      0.89      0.94        18
#            4       0.96      1.00      0.98        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       0.78      1.00      0.88        18
#            8       1.00      1.00      1.00        17
#            9       0.95      1.00      0.98        21
#           10       1.00      0.88      0.93        16
#           11       1.00      0.88      0.94        17
#           12       1.00      1.00      1.00        29
#           13       1.00      0.95      0.97        20
#           14       0.90      0.75      0.82        12
#           15       0.95      1.00      0.98        20
#           16       1.00      0.89      0.94        18
#           17       1.00      1.00      1.00        29
#           18       1.00      0.86      0.92        21
#           19       1.00      0.95      0.97        20
#           20       0.95      1.00      0.97        19
#           21       1.00      1.00      1.00        18
#           22       0.89      1.00      0.94        17
#
#     accuracy                           0.96       440
#    macro avg       0.96      0.96      0.96       440
# weighted avg       0.97      0.96      0.96       440
#
#
# Logistic Regression Precision score :  0.9646964483712975
#
# Logistic Regression Recall score :  0.9564669807316867
#
# *******************************************
# Naive Bayes : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        17
#            9       1.00      1.00      1.00        21
#           10       1.00      1.00      1.00        16
#           11       0.89      1.00      0.94        17
#           12       1.00      1.00      1.00        29
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        29
#           18       1.00      1.00      1.00        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.88      0.94        17
#
#     accuracy                           1.00       440
#    macro avg       1.00      0.99      0.99       440
# weighted avg       1.00      1.00      1.00       440
#
#
# Naive Bayes Precision score :  0.9952153110047847
#
# Naive Bayes Recall score :  0.9946524064171123
#
# *******************************************
# Support Vector Machine : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       0.96      1.00      0.98        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        17
#            9       0.95      1.00      0.98        21
#           10       1.00      0.94      0.97        16
#           11       0.85      1.00      0.92        17
#           12       1.00      1.00      1.00        29
#           13       1.00      0.95      0.97        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      0.94      0.97        18
#           17       1.00      1.00      1.00        29
#           18       0.95      1.00      0.98        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.82      0.90        17
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.98      0.99       440
# weighted avg       0.99      0.99      0.99       440
#
#
# Support Vector Machine Precision score :  0.9873660850933578
#
# Support Vector Machine Recall score :  0.9843397207367797
#
# *******************************************
# K-Nearest Neighbors : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       0.95      1.00      0.97        18
#            8       1.00      1.00      1.00        17
#            9       0.95      1.00      0.98        21
#           10       1.00      0.88      0.93        16
#           11       0.89      1.00      0.94        17
#           12       1.00      1.00      1.00        29
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      0.94      0.97        18
#           17       1.00      1.00      1.00        29
#           18       0.95      1.00      0.98        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.88      0.94        17
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440
#
#
# K-Nearest Neighbors Precision score :  0.9886907351022184
#
# K-Nearest Neighbors Recall score :  0.9864453357100416
#
# *******************************************
# Decision Tree : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       0.95      1.00      0.98        20
#            3       1.00      0.94      0.97        18
#            4       1.00      0.96      0.98        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       0.95      1.00      0.97        18
#            8       1.00      1.00      1.00        17
#            9       1.00      1.00      1.00        21
#           10       1.00      0.94      0.97        16
#           11       0.94      0.88      0.91        17
#           12       1.00      1.00      1.00        29
#           13       1.00      1.00      1.00        20
#           14       1.00      0.83      0.91        12
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        29
#           18       0.95      1.00      0.98        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       0.90      1.00      0.95        18
#           22       0.89      0.94      0.91        17
#
#     accuracy                           0.98       440
#    macro avg       0.98      0.98      0.98       440
# weighted avg       0.98      0.98      0.98       440
#
#
# Decision Tree Precision score :  0.9809401689485422
#
# Decision Tree Recall score :  0.9772884386854975
#
# *******************************************
# Extra Trees : Classification report
#               precision    recall  f1-score   support
#
#            1       0.95      0.91      0.93        22
#            2       0.95      0.90      0.92        20
#            3       0.94      0.89      0.91        18
#            4       0.96      0.92      0.94        26
#            5       1.00      1.00      1.00        25
#            6       0.89      1.00      0.94        17
#            7       0.80      0.89      0.84        18
#            8       0.94      1.00      0.97        17
#            9       0.95      1.00      0.98        21
#           10       0.71      0.75      0.73        16
#           11       0.79      0.65      0.71        17
#           12       0.92      0.83      0.87        29
#           13       0.72      0.90      0.80        20
#           14       1.00      0.75      0.86        12
#           15       0.87      1.00      0.93        20
#           16       0.71      0.56      0.63        18
#           17       1.00      1.00      1.00        29
#           18       0.88      1.00      0.93        21
#           19       1.00      0.85      0.92        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       0.79      0.88      0.83        17
#
#     accuracy                           0.90       440
#    macro avg       0.90      0.89      0.89       440
# weighted avg       0.91      0.90      0.90       440
#
#
# Extra Trees Precision score :  0.8989841255789505
#
# Extra Trees Recall score :  0.8942045062319818
#
# *******************************************
# Random Forest : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        17
#            9       1.00      1.00      1.00        21
#           10       1.00      1.00      1.00        16
#           11       0.94      1.00      0.97        17
#           12       1.00      1.00      1.00        29
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        29
#           18       1.00      1.00      1.00        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.94      0.97        17
#
#     accuracy                           1.00       440
#    macro avg       1.00      1.00      1.00       440
# weighted avg       1.00      1.00      1.00       440
#
#
# Random Forest Precision score :  0.9974747474747474
#
# Random Forest Recall score :  0.9973262032085561
#
# *******************************************
# Bagging : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        17
#            9       1.00      1.00      1.00        21
#           10       1.00      0.94      0.97        16
#           11       0.94      1.00      0.97        17
#           12       1.00      1.00      1.00        29
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        29
#           18       0.95      1.00      0.98        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.94      0.97        17
#
#     accuracy                           1.00       440
#    macro avg       1.00      0.99      0.99       440
# weighted avg       1.00      1.00      1.00       440
#
#
# Bagging Precision score :  0.995408631772268
#
# Bagging Recall score :  0.9944852941176471
#
# *******************************************
# Gradient Boosting : Classification report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        18
#            4       0.96      1.00      0.98        26
#            5       1.00      1.00      1.00        25
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        17
#            9       1.00      1.00      1.00        21
#           10       1.00      0.94      0.97        16
#           11       0.85      1.00      0.92        17
#           12       1.00      0.93      0.96        29
#           13       0.95      0.95      0.95        20
#           14       1.00      1.00      1.00        12
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        18
#           17       1.00      1.00      1.00        29
#           18       0.95      0.95      0.95        21
#           19       1.00      1.00      1.00        20
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        18
#           22       1.00      0.94      0.97        17
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440
#
#
# Gradient Boosting Precision score :  0.9870610870610871
#
# Gradient Boosting Recall score :  0.9869132684421732
#
# *******************************************

# %%
classifier=models['Gradient Boosting']
classifier.fit(X_train,Y_train)
predictions=classifier.predict(X_test)

# %% [markdown]
# # Predictive system

# %%
def recommendation(N,P,k,temperature,humidity,ph,rainfal):
    features=np.array([[N,P,k,temperature,humidity,ph,rainfal]])
    transformed_features=scaler.fit_transform(features)
    prediction=classifier.predict(transformed_features)
    print(prediction)
    return prediction[0]

# %%
crop_map={}
for crop in crops:
    crop_map[label_map[crop]]=crop
crop_map
# Out:
# {1: 'mango',
#  2: 'mungbean',
#  3: 'orange',
#  4: 'cotton',
#  5: 'chickpea',
#  6: 'grapes',
#  7: 'blackgram',
#  8: 'pomegranate',
#  9: 'kidneybeans',
#  10: 'mothbeans',
#  11: 'jute',
#  12: 'coffee',
#  13: 'maize',
#  14: 'papaya',
#  15: 'muskmelon',
#  16: 'pigeonpeas',
#  17: 'apple',
#  18: 'lentil',
#  19: 'watermelon',
#  20: 'coconut',
#  21: 'banana',
#  22: 'rice'}

# %%
data[data['label_num'] == 9]
# Out:
#       N   P   K  temperature   humidity        ph    rainfall  label_num
# 310  28  58  24    19.727025  18.281730  5.748190  143.763089          9
# 342  28  66  23    21.539892  24.253862  5.996161  120.691304          9
# 346   0  65  15    23.461683  23.221976  5.645436   95.842534          9
# 334   1  62  23    15.435461  18.374779  5.607808  139.030203          9
# 324  11  71  17    19.919179  21.473242  5.746448   82.685544          9
# ..   ..  ..  ..          ...        ...       ...         ...        ...
# 398  27  63  19    20.934099  21.189301  5.562202  133.191442          9
# 385  32  68  19    24.628350  18.183252  5.514234  149.744103          9
# 337   6  62  22    20.530527  18.092240  5.824091  120.450929          9
# 396  30  63  16    23.605066  21.905396  5.525905  100.597873          9
# 306  17  57  21    19.883940  20.315641  5.789214   60.919748          9
#
# [100 rows x 8 columns]

# %%
# input 1

N = 80
P = 10
k = 50
temperature = 40.0
humidity = 20
ph = 100
rainfall = 100

predict = recommendation(N,P,k,temperature,humidity,ph,rainfall)
if predict in crop_map:
    print("{} is a best crop to be cultivated ".format(crop_map[22]))
else:
    print("Sorry are not able to recommend a proper crop for this environment")
# Out:
# [9]
# rice is a best crop to be cultivated

# %%
N = 9
P = 35
k = 20
temperature = 27.4
humidity = 80.9
ph = 6.9
rainfall = 40.53

predict = recommendation(N,P,k,temperature,humidity,ph,rainfall)
if predict in crop_map:
    print("{} is a best crop to be cultivated ".format(crop_map[predict]))
else:
    print("Sorry are not able to recommend a proper crop for this environment")
# Out:
# [9]
# kidneybeans is a best crop to be cultivated
